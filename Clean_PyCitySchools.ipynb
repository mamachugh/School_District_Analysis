# %%
import pandas as pd 
import numpy as np

# %%
schools_data = pd.read_csv("Resources/schools_complete.csv")
student_data = pd.read_csv("Resources/students_complete.csv")

# %%
schools_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
sample = [student_data[0:11]]
sample
# Out:
# [    Student ID       student_name gender grade        school_name  \
#  0            0       Paul Bradley      M   9th  Huang High School
#  1            1       Victor Smith      M  12th  Huang High School
#  2            2    Kevin Rodriguez      M  12th  Huang High School
#  3            3  Dr. Richard Scott      M  12th  Huang High School
#  4            4         Bonnie Ray      F   9th  Huang High School
#  5            5      Bryan Miranda      M   9th  Huang High School
#  6            6      Sheena Carter      F  11th  Huang High School
#  7            7       Nicole Baker      F  12th  Huang High School
#  8            8       Michael Roth      M  10th  Huang High School
#  9            9     Matthew Greene      M  10th  Huang High School
#  10          10   Andrew Alexander      M  10th  Huang High School
#
#      reading_score  math_score
#  0              66          79
#  1              94          61
#  2              90          60
#  3              67          58
# ...

# %%
student_data.count()

student_data.isnull().sum()
# Out:
# Student ID       0
# student_name     0
# gender           0
# grade            0
# school_name      0
# reading_score    0
# math_score       0
# dtype: int64

# %%
schools_data.dtypes
# Out:
# School ID       int64
# school_name    object
# type           object
# size            int64
# budget          int64
# dtype: object

# %%
student_data.dtypes

#print(student_data)
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# dtype: object

# %%
student_name = student_data["student_name"].tolist()

sample = [student_name[0:11]]
sample
# Out:
# [['Paul Bradley',
#   'Victor Smith',
#   'Kevin Rodriguez',
#   'Dr. Richard Scott',
#   'Bonnie Ray',
#   'Bryan Miranda',
#   'Sheena Carter',
#   'Nicole Baker',
#   'Michael Roth',
#   'Matthew Greene',
#   'Andrew Alexander']]

# %%
# Split the student name and determine the length of the split name.

for name in student_name:
    print(name.split(), len(name.split()))
# Out:
# '] 2
# ['Savannah', 'Smith'] 2
# ['Heather', 'Hunter'] 2
# ['Lisa', 'Tucker'] 2
# ['Renee', 'Moore'] 2
# ['Nicole', 'White', 'MD'] 3
# ['Keith', 'King'] 2
# ['Amanda', 'Skinner', 'MD'] 3
# ['Marcus', 'Wallace'] 2
# ['James', 'Horton'] 2
# ['Darrell', 'Simpson'] 2
# ['Diane', 'Rush'] 2
# ['Christine', 'Guerrero'] 2
# ['Rita', 'Perez'] 2
# ['Sarah', 'Williams'] 2
# ['Jason', 'Key'] 2
# ['Christine', 'Smith'] 2
# ['Jennifer', 'Dixon'] 2
# ['Timothy', 'Wilson'] 2
# ['Maxwell', 'Anderson'] 2
# ['Christina', 'Robinson'] 2
# ['Abigail', 'Durham'] 2
# ['Charlotte', 'Graham'] 2
# ['Tanya', 'Barnes'] 2
# ['Theresa', 'Gentry'] 2
# ['Donald', 'Nicholson'] 2
# ['Nathan', 'Smith'] 2
# ['Sarah', 'Briggs'] 2
# ['Joshua', 'Thomas'] 2
# ['Alexander', 'Wilson'] 2
# ['David', 'Smith'] 2
# ['Rebecca', 'Reilly'] 2
# ['Paul', 'Bowers'] 2
# ['Teresa', 'Chapman'] 2
# ['Kimberly', 'Case'] 2
# ['Guy', 'Goodwin'] 2
# ['Brenda', 'Rivera'] 2
# ['Gregory', 'Shepherd'] 2
# ['Kenneth', 'Simon'] 2
# ...

# %%
students_to_fix = []

for name in student_name:
    if len(name.split()) >=3:
        students_to_fix.append(name)

len(students_to_fix)
# Out:
# 1531

# %%
# using list indexing
# to get first and last element of list 
sample = [ students_to_fix[0:11] ] 

print(sample)
# Out:
# [['Dr. Richard Scott', 'Dr. Jordan Carson', 'Madeline Snyder MD', 'Mr. Dylan Taylor MD', 'Dr. Scott Gill', 'Miss Madison Everett', 'Virginia Ramirez MD', 'Joseph Morales III', 'Angela Perkins DVM', 'Heather Allen MD', 'Luke Lowery MD']]

# %%
## Add the prefixes less than or equal to 4 to a new list

prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

print(prefixes)
# Out:
# ['Dr.', 'Dr.', 'Mr.', 'Dr.', 'Miss', 'Luke', 'Dr.', 'Mrs.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mary', 'Mrs.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'John', 'Mr.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Dale', 'Dr.', 'Dr.', 'Dr.', 'Ms.', 'Dr.', 'Dr.', 'Mr.', 'Mrs.', 'Amy', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Lisa', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mr.', 'Mark', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Cody', 'Mr.', 'Dr.', 'Mr.', 'Ms.', 'Dr.', 'Mr.', 'Mrs.', 'Sara', 'Mr.', 'Mrs.', 'Dr.', 'Mr.', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mrs.', 'Mr.', 'Mrs.', 'Dr.', 'Ryan', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Dr.', 'John', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Dr.', 'Mrs.', 'Mr.', 'Mr.', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Miss', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Miss', 'Tony', 'Dr.', 'M
# ...

# %%
suffixes = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3: 
        suffixes.append(name.split()[-1])

print(suffixes)
# Out:
# ['MD', 'MD', 'MD', 'III', 'DVM', 'MD', 'MD', 'MD', 'DDS', 'DVM', 'II', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'MD', 'MD', 'PhD', 'MD', 'DVM', 'Lee', 'MD', 'DDS', 'MD', 'MD', 'MD', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DVM', 'MD', 'MD', 'PhD', 'IV', 'MD', 'DDS', 'DDS', 'DDS', 'MD', 'DDS', 'MD', 'DVM', 'IV', 'MD', 'DDS', 'MD', 'MD', 'DVM', 'Jr.', 'MD', 'PhD', 'II', 'MD', 'DDS', 'DDS', 'DDS', 'Jr.', 'III', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DDS', 'DVM', 'DDS', 'DVM', 'MD', 'DDS', 'PhD', 'DDS', 'DDS', 'Jr.', 'Jr.', 'DVM', 'DDS', 'MD', 'MD', 'DVM', 'DDS', 'DVM', 'Jr.', 'MD', 'Jr.', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'DDS', 'DVM', 'Cox', 'DVM', 'MD', 'Jr.', 'MD', 'DDS', 'MD', 'MD', 'DDS', 'DDS', 'Roy', 'DDS', 'DDS', 'DDS', 'II', 'PhD', 'MD', 'PhD', 'DDS', 'MD', 'DDS', 'Jr.', 'Day', 'DDS', 'MD', 'PhD', 'DDS', 'Jr.', 'DDS', 'MD', 'MD', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'PhD', 'DVM', 'DDS', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'Jr.', 'DDS', 'Jr.', 'MD', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'MD', 'III', 'DVM', 'PhD', 'J
# ...

# %%
## Get the unique items in the "prefixes" list
set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
## Get the unique items in the "suffixes" list
set(suffixes)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
prefixes_suffixes = ["Dr. ","Mr. ","Ms. ","Miss ","Mrs. "," MD"," DDS"," DVM"," PhD"]
prefixes_suffixes
# Out:
# ['Dr. ', 'Mr. ', 'Ms. ', 'Miss ', 'Mrs. ', ' MD', ' DDS', ' DVM', ' PhD']

# %%
#student_data["student_name"].str.replace()
word = 0

for word in prefixes_suffixes:
    student_data["student_name"] = student_data["student_name"].str.replace(word,"")

# %%
student_data.head(10)
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
# 7           7     Nicole Baker      F  12th  Huang High School             96
# 8           8     Michael Roth      M  10th  Huang High School             95
# 9           9   Matthew Greene      M  10th  Huang High School             96
#
#    math_score
# 0          79
# 1          61
# 2          60
# 3          58
# 4          84
# 5          94
# ...

# %%
clean_names = student_data["student_name"].tolist()

sample = [clean_names[0:11]]
sample
# Out:
# [['Paul Bradley',
#   'Victor Smith',
#   'Kevin Rodriguez',
#   'Richard Scott',
#   'Bonnie Ray',
#   'Bryan Miranda',
#   'Sheena Carter',
#   'Nicole Baker',
#   'Michael Roth',
#   'Matthew Greene',
#   'Andrew Alexander']]

# %%
students_fixed = []

for name in clean_names:
    if len(name.split()) >=3:
        students_fixed.append(name)

len(students_fixed)
# Out:
# 151

# %%
sample = [students_fixed[0:11]]

print(sample)
# Out:
# [['Joseph Morales III', 'Xavier Bell II', 'David Miller Jr.', 'Reginald Garcia IV', 'Kevin Brown IV', 'William Washington Jr.', 'Juan Bryant II', 'Kenneth Paul Jr.', 'Scott Rivers III', 'Mark Myers Jr.', 'Michael Norton Jr.']]
